# %% [markdown]
# # TACHE 1 : Installation des dépendances et exécution de la session Spark

# %%
#installer PySpark
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fa8d03d2-e841-49c6-9d14-9b9648127a20/lib/python3.9/site-packages (3.4.1)
# Requirement already satisfied: py4j==0.10.9.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fa8d03d2-e841-49c6-9d14-9b9648127a20/lib/python3.9/site-packages (from pyspark) (0.10.9.7)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-fa8d03d2-e841-49c6-9d14-9b9648127a20/bin/python -m pip install --upgrade pip' command.

# %%
#créer une session Spark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("spark").getOrCreate()

# %% [markdown]
# # TACHE 2: Cloner et explorer le jeu de données

# %%
#cloner le jeu de données sur le diabète depuis le dépôt github
# !git clone https://github.com/education454/diabetes_dataset
# Out:
# Cloning into 'diabetes_dataset'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), 13.00 KiB | 1.62 MiB/s, done.

# %%
#vérifier si le jeu de données existe
!#fill here diabetes_dataset
filePath="file:/databricks/driver/diabetes_dataset"
dbutils.fs.ls(filePath)
# Out:
# Out[16]: [FileInfo(path='file:/databricks/driver/diabetes_dataset/.git/', name='.git/', size=4096, modificationTime=1690271597983),
#  FileInfo(path='file:/databricks/driver/diabetes_dataset/new_test.csv', name='new_test.csv', size=208, modificationTime=1690271597983),
#  FileInfo(path='file:/databricks/driver/diabetes_dataset/diabetes.csv', name='diabetes.csv', size=62058, modificationTime=1690271597983)]

# %%
#créer un dataframe spark
df = spark.read.csv('file:/databricks/driver/diabetes_dataset/diabetes.csv', header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-1798151190067622>:3
#       1 #créer un dataframe spark
#       2 df = spark.read.csv('file:/databricks/driver/diabetes_dataset/diabetes.csv', header=True, inferSchema=True)
# ----> 3 dislpay(df)
#
# NameError: name 'dislpay' is not defined

# %%
#afficher le dataframe
#fill here
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Pregnancies</th><th>Glucose</th><th>BloodPressure</th><th>SkinThickness</th><th>Insulin</th><th>BMI</th><th>DiabetesPedigreeFunction</th><th>Age</th><th>Outcome</th></tr></thead><tbody><tr><td>2</td><td>138</td><td>62</td><td>35</td><td>0</td><td>33.6</td><td>0.127</td><td>47</td><td>1</td></tr><tr><td>0</td><td>84</td><td>82</td><td>31</td><td>125</td><td>38.2</td><td>0.233</td><td>23</td><td>0</td></tr><tr><td>0</td><td>145</td><td>0</td><td>0</td><td>0</td><td>44.2</td><td>0.63</td><td>31</td><td>1</td></tr><tr><td>0</td><td>135</td><td>68</td><td>42</td><td>250</td><td>42.3</td><td>0.365</td><td>24</td><td>1</td></tr><tr><td>1</td><td>139</td><td>62</td><td>41</td><td>480</td><td>40.7</td><td>0.536</td><td>21</td><td>0</td></tr><tr><td>0</td><td>173</td><td>78</td><td>32</td><td>265</td><td>46.5</td><td>1.159</td><td>58</td><td>0</td></tr><tr><td>4</td><td>99</td><td>72</td><td>17</td><td>0</td><td>25.6</td><td>0.294</td><td>28</td><td>0</td></tr><tr><td>8</td><td>194</td><td>80</td><td>0</td><td>0</td><td>26.1</td><td>0.551</td><td>67</td><td>0</td></tr><tr><td>2</td><td>83</td><td>65</td><td>28</td><td>66</td><td>36.8</td><td>0.629</td><td>24</td><td>0</td></tr><tr><
nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Outcome: integer (nullable = true)

# %%
#afficher le nombre de lignes et le nombre de colonnes du jeu de données
#fill here
str(df.count()) + ' ' + str(len(df.columns))
# Out:
# Out[48]: '2000 9'

# %%
#compter le nombre total de diabétiques et de non-diabétiques
df.groupby('Outcome').count().display()
#fill here.#fill here
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Outcome</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>684</td></tr><tr><td>0</td><td>1316</td></tr></tbody></table></div>

# %%
#obtenir les statistiques sommaires
#fill here
df.describe().show()
# Out:
# +-------+-----------------+------------------+------------------+-----------------+-----------------+------------------+------------------------+------------------+------------------+
# |summary|      Pregnancies|           Glucose|     BloodPressure|    SkinThickness|          Insulin|               BMI|DiabetesPedigreeFunction|               Age|           Outcome|
# +-------+-----------------+------------------+------------------+-----------------+-----------------+------------------+------------------------+------------------+------------------+
# |  count|             2000|              2000|              2000|             2000|             2000|              2000|                    2000|              2000|              2000|
# |   mean|           3.7035|          121.1825|           69.1455|           20.935|           80.254|32.192999999999984|     0.47092999999999974|           33.0905|             0.342|
# | stddev|3.306063032730656|32.068635649902916|19.188314815604098|16.10324290992682|111.1805335457595| 8.149900701279762|      0.3235525586811429|11.786423106049496|0.4744982342297426|
# |    min|                0|                 0|                 0|                0|                0|               0.0|                   0.078|                21|                 0|
# |    max|               17|               199|               122|              110|              744|              80.6|                    2.42|                81|                 1|
# +-------+-----------------+------------------+------------------+-----------------+-----------------+------------------+------------------------+------------------+------------------+

# %% [markdown]
# # TACHE 3: Nettoyage et préparation des données

# %%
#vérification des valeurs nulles
for col in df.columns:
  print(col+ ":", df[df[col].isNull()].count())
# Out:
# Pregnancies: 0
# Glucose: 0
# BloodPressure: 0
# SkinThickness: 0
# Insulin: 0
# BMI: 0
# DiabetesPedigreeFunction: 0
# Age: 0
# Outcome: 0

# %%
#rechercher les valeurs inutiles présentes
def count_zeros():
  column_list= ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
  for i in column_list:
    print(i+ ":", df[df[i]==0].count())

# %%
count_zeros()
# Out:
# Glucose: 13
# BloodPressure: 90
# SkinThickness: 573
# Insulin: 956
# BMI: 28

# %%
    #calculer et remplacer les valeurs inutiles par la valeur moyenne
from pyspark.sql.functions import *
df.display()
for i in df.columns[1:6]:
  data = df.select(avg(i).alias('avg')).first().asDict()['avg']
  print("Mean value for {} is {}".format(i,int(data)))
  df = df.withColumn(i, when(df[i]== 0, int(data)).otherwise(df[i]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Pregnancies</th><th>Glucose</th><th>BloodPressure</th><th>SkinThickness</th><th>Insulin</th><th>BMI</th><th>DiabetesPedigreeFunction</th><th>Age</th><th>Outcome</th></tr></thead><tbody><tr><td>2</td><td>138</td><td>62</td><td>35</td><td>0</td><td>33.6</td><td>0.127</td><td>47</td><td>1</td></tr><tr><td>0</td><td>84</td><td>82</td><td>31</td><td>125</td><td>38.2</td><td>0.233</td><td>23</td><td>0</td></tr><tr><td>0</td><td>145</td><td>0</td><td>0</td><td>0</td><td>44.2
#nous choisirons toutes les caractéristiques d'entrée de notre modèle comme étant des co_relation similaires
from pyspark.ml.feature import VectorAssembler #fill here
#définition d'une nouvelle colonne de caractéristiques
assembler = VectorAssembler(inputCols=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age'], outputCol='features')
output_data = assembler.transform(df)
output_data.show()
df=output_data
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+--------------------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|            features|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+--------------------+
# |          2|    138|           62|           35|     80|33.6|                   0.127| 47|      1|[2.0,138.0,62.0,3...|
# |          0|     84|           82|           31|    125|38.2|                   0.233| 23|      0|[0.0,84.0,82.0,31...|
# |          0|    145|           69|           20|     80|44.2|                    0.63| 31|      1|[0.0,145.0,69.0,2...|
# |          0|    135|           68|           42|    250|42.3|                   0.365| 24|      1|[0.0,135.0,68.0,4...|
# |          1|    139|           62|           41|    480|40.7|                   0.536| 21|      0|[1.0,139.0,62.0,4...|
# |          0|    173|           78|           32|    265|46.5|                   1.159| 58|      0|[0.0,173.0,78.0,3...|
# |          4|     99|           72|           17|     80|25.6|                   0.294| 28|      0|[4.0,99.0,72.0,17...|
# |          8|    194|           80|           20|     80|26.1|                   0.551| 67|      0|[8.0,194.0,80.0,2...|
# |          2|     83|           65|           28|     66|36.8|                   0.629| 24|      0|[2.0,83.0,65.0,28...|
# |          2|     89|           90|           30|     80|33.5|                   0.292| 42|      0|[2.0,89.0,90.0,30...|
# |          4|     99|           68|           38|     80|32.8|                   0.145| 33|      0|[4.0,99.0,68.0,38...|
# |          4|    125|           70|           18|    122|28.9|                   1.144| 45|      1|[4.0,125.0,70.0,1...|
# |          3|     80|           69|           20|     80|32.0|                   0.174| 22|      0|[3.0,80.0,69.0,20...|
# |          6|    166|           74|           20|     80|26.6|                   0.304| 66|      0|[6.0,166.0,74.0,2...|
# |          5|    110|           68|           20|     80|26.0|                   0.292| 30|      0|[5.0,110.0,68.0,2...|
# |          2|     81|           72|           15|     76|30.1|                   0.547| 25|      0|[2.0,81.0,72.0,15...|
# |          7|    195|           70|           33|    145|25.1|                   0.163| 55|      1|[7.0,195.0,70.0,3...|
# |          6|    154|           74|           32|    193|29.3|                   0.839| 39|      0|[6.0,154.0,74.0,3...|
# |          2|    117|           90|           19|     71|25.2|                   0.313| 21|      0|[2.0,117.0,90.0,1...|
# |          3|     84|           72|           32|     80|37.2|                   0.267| 28|      0|[3.0,84.0,72.0,32...|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+--------------------+
# only showing top 20 rows

# %%
#afficher le schéma
#fill here
df.printSchema()
# Out:
# root
#  |-- Pregnancies: integer (nullable = true)
#  |-- Glucose: integer (nullable = true)
#  |-- BloodPressure: integer (nullable = true)
#  |-- SkinThickness: integer (nullable = true)
#  |-- Insulin: integer (nullable = true)
#  |-- BMI: double (nullable = true)
#  |-- DiabetesPedigreeFunction: double (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Outcome: integer (nullable = true)
#  |-- features: vector (nullable = true)

# %%
#afficher le dataframe
#fill here
df.show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+--------------------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|            features|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+--------------------+
# |          2|    138|           62|           35|     80|33.6|                   0.127| 47|      1|[2.0,138.0,62.0,3...|
# |          0|     84|           82|           31|    125|38.2|                   0.233| 23|      0|[0.0,84.0,82.0,31...|
# |          0|    145|           69|           20|     80|44.2|                    0.63| 31|      1|[0.0,145.0,69.0,2...|
# |          0|    135|           68|           42|    250|42.3|                   0.365| 24|      1|[0.0,135.0,68.0,4...|
# |          1|    139|           62|           41|    480|40.7|                   0.536| 21|      0|[1.0,139.0,62.0,4...|
# |          0|    173|           78|           32|    265|46.5|                   1.159| 58|      0|[0.0,173.0,78.0,3...|
# |          4|     99|           72|           17|     80|25.6|                   0.294| 28|      0|[4.0,99.0,72.0,17...|
# |          8|    194|           80|           20|     80|26.1|                   0.551| 67|      0|[8.0,194.0,80.0,2...|
# |          2|     83|           65|           28|     66|36.8|                   0.629| 24|      0|[2.0,83.0,65.0,28...|
# |          2|     89|           90|           30|     80|33.5|                   0.292| 42|      0|[2.0,89.0,90.0,30...|
# |          4|     99|           68|           38|     80|32.8|                   0.145| 33|      0|[4.0,99.0,68.0,38...|
# |          4|    125|           70|           18|    122|28.9|                   1.144| 45|      1|[4.0,125.0,70.0,1...|
# |          3|     80|           69|           20|     80|32.0|                   0.174| 22|      0|[3.0,80.0,69.0,20...|
# |          6|    166|           74|           20|     80|26.6|                   0.304| 66|      0|[6.0,166.0,74.0,2...|
# |          5|    110|           68|           20|     80|26.0|                   0.292| 30|      0|[5.0,110.0,68.0,2...|
# |          2|     81|           72|           15|     76|30.1|                   0.547| 25|      0|[2.0,81.0,72.0,15...|
# |          7|    195|           70|           33|    145|25.1|                   0.163| 55|      1|[7.0,195.0,70.0,3...|
# |          6|    154|           74|           32|    193|29.3|                   0.839| 39|      0|[6.0,154.0,74.0,3...|
# |          2|    117|           90|           19|     71|25.2|                   0.313| 21|      0|[2.0,117.0,90.0,1...|
# |          3|     84|           72|           32|     80|37.2|                   0.267| 28|      0|[3.0,84.0,72.0,32...|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # TACHE 5: Diviser l'ensemble de données et construire le modèle

# %%
#create final data
#nous allons maintenant utiliser le modèle de l'algorithme de régression logistique
from pyspark.ml.classification import LogisticRegression#fill here
# Sélection des caractéristiques et de la colonne des résultats
final_data = output_data.select('features', 'Outcome')

# %%
#afficher le schéma de final data
#fill here
final_data.printSchema()
# Out:
# root
#  |-- features: vector (nullable = true)
#  |-- Outcome: integer (nullable = true)

# %%
#diviser l'ensemble de données 
train, test = final_data.randomSplit([0.7,0.3])
#construire le modèle
models = LogisticRegression(labelCol='Outcome')

# %%
#entraîner le modèle
model = models.fit(train)

# %%
#résumé du modèle
summary = model.summary

# %%
summary.predictions.show()#fill here
# Out:
# +--------------------+-------+--------------------+--------------------+----------+
# |            features|Outcome|       rawPrediction|         probability|prediction|
# +--------------------+-------+--------------------+--------------------+----------+
# |[0.0,57.0,60.0,20...|    0.0|[4.14713851737125...|[0.98443646246752...|       0.0|
# |[0.0,57.0,60.0,20...|    0.0|[4.14713851737125...|[0.98443646246752...|       0.0|
# |[0.0,67.0,76.0,20...|    0.0|[2.53690829353840...|[0.92668906392408...|       0.0|
# |[0.0,73.0,69.0,20...|    0.0|[4.35034763605004...|[0.98726202305044...|       0.0|
# |[0.0,73.0,69.0,20...|    0.0|[4.35034763605004...|[0.98726202305044...|       0.0|
# |[0.0,74.0,52.0,10...|    0.0|[3.73474344181041...|[0.97667762519592...|       0.0|
# |[0.0,78.0,88.0,29...|    0.0|[2.81866299541699...|[0.94367604467811...|       0.0|
# |[0.0,84.0,64.0,22...|    0.0|[2.53671000530517...|[0.92667559178708...|       0.0|
# |[0.0,84.0,64.0,22...|    0.0|[2.53671000530517...|[0.92667559178708...|       0.0|
# |[0.0,84.0,64.0,22...|    0.0|[2.53671000530517...|[0.92667559178708...|       0.0|
# |[0.0,84.0,82.0,31...|    0.0|[2.72125789709511...|[0.93826943119611...|       0.0|
# |[0.0,84.0,82.0,31...|    0.0|[2.72125789709511...|[0.93826943119611...|       0.0|
# |[0.0,84.0,82.0,31...|    0.0|[2.72125789709511...|[0.93826943119611...|       0.0|
# |[0.0,86.0,68.0,32...|    0.0|[2.68734644317272...|[0.93627584464131...|       0.0|
# |[0.0,91.0,68.0,32...|    0.0|[2.23863254688585...|[0.90366548147402...|       0.0|
# |[0.0,91.0,80.0,20...|    0.0|[2.50002620953608...|[0.92414365734421...|       0.0|
# |[0.0,91.0,80.0,20...|    0.0|[2.50002620953608...|[0.92414365734421...|       0.0|
# |[0.0,93.0,60.0,20...|    0.0|[2.40709728374732...|[0.91736690827119...|       0.0|
# |[0.0,93.0,60.0,20...|    0.0|[2.40709728374732...|[0.91736690827119...|       0.0|
# |[0.0,93.0,60.0,20...|    0.0|[2.40709728374732...|[0.91736690827119...|       0.0|
# +--------------------+-------+--------------------+--------------------+----------+
# only showing top 20 rows

# %% [markdown]
# # TACHE 6: Évaluer et sauvegarder le modèle

# %%
# Par défaut, il utilise l'aire sous le ROC comme matrice de performance.
from pyspark.ml.evaluation import BinaryClassificationEvaluator
predictions = model.evaluate(test)

# %%
predictions.predictions.show(10)
# Out:
# +--------------------+-------+--------------------+--------------------+----------+
# |            features|Outcome|       rawPrediction|         probability|prediction|
# +--------------------+-------+--------------------+--------------------+----------+
# |[0.0,67.0,76.0,20...|      0|[2.53690829353840...|[0.92668906392408...|       0.0|
# |[0.0,74.0,52.0,10...|      0|[3.73474344181041...|[0.97667762519592...|       0.0|
# |[0.0,74.0,52.0,10...|      0|[3.73474344181041...|[0.97667762519592...|       0.0|
# |[0.0,78.0,88.0,29...|      0|[2.81866299541699...|[0.94367604467811...|       0.0|
# |[0.0,84.0,82.0,31...|      0|[2.72125789709511...|[0.93826943119611...|       0.0|
# |[0.0,86.0,68.0,32...|      0|[2.68734644317272...|[0.93627584464131...|       0.0|
# |[0.0,91.0,68.0,32...|      0|[2.23863254688585...|[0.90366548147402...|       0.0|
# |[0.0,91.0,68.0,32...|      0|[2.23863254688585...|[0.90366548147402...|       0.0|
# |[0.0,93.0,60.0,25...|      0|[2.77297977890413...|[0.94119811704935...|       0.0|
# |[0.0,94.0,69.0,20...|      0|[2.67370223668659...|[0.93545692302497...|       0.0|
# +--------------------+-------+--------------------+--------------------+----------+
# only showing top 10 rows

# %%
#en utilisant l'évaluateur de classification binaire
evaluator =BinaryClassificationEvaluator(rawPredictionCol='rawPrediction', labelCol='Outcome')
# Quelle est la justesse (accuracy) de notre modèle ?
evaluator.evaluate(predictions.predictions)
# Out:
# Out[144]: 0.8277250124970404

# %%
#sauvegarder le modèle
model.save("model")

# %% [markdown]
# # TACHE 7: Prédiction sur de nouvelles données avec le modèle sauvegardé

# %%
#créer un nouveau dataframe Spark
test_df = spark.read.csv("file:/databricks/driver/diabetes_dataset/new_test.csv", header=True, inferSchema=True)

# %%
#afficher le schéma
test_df.printSchema()
# Out:
# root
#  |-- Pregnancies: integer (nullable = true)
#  |-- Glucose: integer (nullable = true)
#  |-- BloodPressure: integer (nullable = true)
#  |-- SkinThickness: integer (nullable = true)
#  |-- Insulin: integer (nullable = true)
#  |-- BMI: double (nullable = true)
#  |-- DiabetesPedigreeFunction: double (nullable = true)
#  |-- Age: integer (nullable = true)

# %%
#créer une colonne fusionnée supplémentaire
test_data = assembler.transform(test_df)

# %%
#afficher le schéma
#fill here
test_data.printSchema()
# Out:
# root
#  |-- Pregnancies: integer (nullable = true)
#  |-- Glucose: integer (nullable = true)
#  |-- BloodPressure: integer (nullable = true)
#  |-- SkinThickness: integer (nullable = true)
#  |-- Insulin: integer (nullable = true)
#  |-- BMI: double (nullable = true)
#  |-- DiabetesPedigreeFunction: double (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- features: vector (nullable = true)

# %%
#utiliser le modèle pour faire des prédictions
results = model.transform(test_data)
results.printSchema()
# Out:
# root
#  |-- Pregnancies: integer (nullable = true)
#  |-- Glucose: integer (nullable = true)
#  |-- BloodPressure: integer (nullable = true)
#  |-- SkinThickness: integer (nullable = true)
#  |-- Insulin: integer (nullable = true)
#  |-- BMI: double (nullable = true)
#  |-- DiabetesPedigreeFunction: double (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = false)

# %%
#afficher les prédictions
results.show()
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+--------------------+--------------------+--------------------+----------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|            features|       rawPrediction|         probability|prediction|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+--------------------+--------------------+--------------------+----------+
# |          1|    190|           78|           38|    150|45.1|                   0.153| 48|[1.0,190.0,78.0,3...|[-2.4522468012373...|[0.07927440013105...|       1.0|
# |          0|     80|           84|           36|    120|50.2|                   0.211| 26|[0.0,80.0,84.0,36...|[1.88341266786355...|[0.86800262099440...|       0.0|
# |          2|    138|           82|           46|    255|52.3|                   0.315| 30|[2.0,138.0,82.0,4...|[-0.7836734208096...|[0.31352872030218...|       1.0|
# |          1|    110|           63|           44|    480|62.7|                   0.616| 32|[1.0,110.0,63.0,4...|[-0.3669789268084...|[0.40927122056074...|       1.0|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+--------------------+--------------------+--------------------+----------+
